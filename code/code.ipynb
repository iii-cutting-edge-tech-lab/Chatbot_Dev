# %%
#製作flask環境
from flask import Flask, request, jsonify
import datetime


app = Flask(__name__)
#建立與mysql的連線
import pymysql

conn = pymysql.connect(host='chatbot_db', port=3306, user='root', passwd='iii', db='chatbot_db',charset='utf8mb4')
print("connect sucess!!")

cur = conn.cursor()
# Out:
# connect sucess!!

# %%
#新增使用者
@app.route('/users',methods=['POST'])
def add_user():
    
    time = datetime.datetime.utcnow().strftime("%Y%m%d%H%M")
    time = int(time)
    a = request.get_json()
    error = None
    #對ststus跟img還沒啥想法先不設定
    if not a['user_register_menu']:
        #完全沒想法先填一
        a['user_register_menu'] = 1
        
    if not a['user_open_id']:
        error = 'Userid is required.'
    elif not a['user_nick_name']:
        error = 'Username is required.'
        
    cur.execute('SELECT user_open_id FROM chatbot_db.users WHERE user_open_id = ("%s")' % (a['user_open_id']))
    test = cur.fetchone() 
    if test:
        error = 'User {} is already registered.'.format(a['user_open_id'])
    
    
    if error is None:
        insertsql=("INSERT INTO chatbot_db.users VALUES ( %s,%s,%s,%s,%s,%s )") 
        value = (a['user_open_id'],a['user_nick_name'],a['user_status'],a['user_img'],time,a['user_register_menu'])
        cur.execute(insertsql , value)
        result =  { "status_describe":"success add user" }
        return jsonify(result)
    
    
    
    result = {"status_describe":"{}".format(error)}
    
    return jsonify(result)

# %%
@app.route('/users/<userid>',methods=['GET'])
def read_user(userid):
    cur.execute(
        'SELECT * FROM chatbot_db.users WHERE user_open_id = ("%s")' % (userid)
        )
    user = cur.fetchone()
    if user is not None:
        #格式跟db內一樣舊部改了，只轉檔
        user = {
            "user_open_id":user[0],
            "user_nick_name":user[1],
            "user_status" : user[2],
            "user_img" : user[3],
            "user_register_date" : user[4],
            "user_register_menu" : user[5]
        }
        return jsonify(user)
    else:
        result = {
            "status_describe":"Please enter the right id!!"
        }
        return jsonify(result)

# %%
@app.route('/users',methods=['GET'])
def read_users():
    cur.execute(
        'SELECT * FROM chatbot_db.users'
        )
    user = cur.fetchall()
    if not user:
        answer = {
          "status_describe":"query string is incompatible"
        }
    else:
        answer = []
        for i in user:
            result = {
                "user_open_id":i[0],
                "user_nick_name":i[1],
                "user_status" : i[2],
                "user_img" : i[3],
                "user_register_date" : i[4],
                "user_register_menu" : i[5]
            }
            answer.append(result)
    
        
    
    return jsonify(answer)

# %%
@app.route('/menu',methods=['POST'])
def add_menu():

    a = request.get_json()
    error = None
        
    if not a['menu_id']:
        error = 'Id is required!!'
    elif not a['menu_content']:
        error = 'Content is required!!'
        
    cur.execute('SELECT menu_id FROM chatbot_db.menus WHERE menu_id = ("%s")' % (a['menu_id']))
    test = cur.fetchone() 
    if test:
        error = 'Menu {} is already registered.'.format(a['menu_id'])
    
    
    if error is None:
        insertsql=("INSERT INTO chatbot_db.menus VALUES ( %s,%s)") 
        value = (a['menu_id'],a['menu_content'])
        cur.execute(insertsql , value)
        result =  { "status_describe":"success add menu" }
        return jsonify(result)
    
    
    
    result = {"status_describe":"{}".format(error)}
    
    return jsonify(result)

# %%
@app.route('/question/sa',methods=['GET'])
def test_sa():
    question = request.args.get('question_id')
    error = None
    if question is None:
        error = 'Please enter the question_id.'
    
    cur.execute('SELECT question_id FROM chatbot_db.assoc_sa_questions WHERE question_id = ("%s")' % (question))
    test = cur.fetchone()
    if not test:
        error = 'Please enter the right question_id'
    
    if error is None:
        readsql=('SELECT * FROM chatbot_db.assoc_sa_questions WHERE question_id=("%s")' % (question))
        cur.execute(readsql)
        result=cur.fetchone()
        result = {
          "question_id":result[0],
          "question_content":result[1],
          "answer1_content":result[2],
          "answer2_content":result[3],
          "answer3_content":result[4],
          "answer4_content":result[5],
          "true_answer":result[6],
          "true_answer_decribe_content" : result[7],
          "external_link": result[8]
        }
        
        
        return jsonify(result)
    
    
    result = {"status_describe":"{}".format(error)}
    
    return jsonify(result)

# %%
@app.route('/question/sysops',methods=['GET'])
def test_sys():
    question = request.args.get('question_id')
    error = None
    if question is None:
        error = 'Please enter the question_id.'
    
    cur.execute('SELECT question_id FROM chatbot_db.assoc_sys_questions WHERE question_id = ("%s")' % (question))
    test = cur.fetchone()
    if not test:
        error = 'Please enter the right question_id'
    
    if error is None:
        readsql=('SELECT * FROM chatbot_db.assoc_sys_questions WHERE question_id=("%s")' % (question))
        cur.execute(readsql)
        result=cur.fetchone()
        result = {
          "question_id":result[0],
          "question_content":result[1],
          "answer1_content":result[2],
          "answer2_content":result[3],
          "answer3_content":result[4],
          "answer4_content":result[5],
          "true_answer":result[6],
          "true_answer_decribe_content" : result[7],
          "external_link": result[8]
        }
        
        
        return jsonify(result)
    
    
    result = {"status_describe":"{}".format(error)}
    
    return jsonify(result)

# %%
@app.route('/question/sysops',methods=['GET'])
def test_sys():
    a=
{
  "question_id":1,
  "question_content":"how are you",
  "answer1_content":"fine",
  "answer2_content":"soso",
  "answer3_content":"great",
  "answer4_content":"bad",
  "true_answer":1,
  "true_answer_decribe_content" : "life is great",
  "external_link": ""
}
return jsonify(a)

# %%
@app.route('/question/devlop',methods=['GET'])
def test_dev():
    question = request.args.get('question_id')
    error = None
    if question is None:
        error = 'Please enter the question_id.'
    
    cur.execute('SELECT question_id FROM chatbot_db.assoc_dev_questions WHERE question_id = ("%s")' % (question))
    test = cur.fetchone()
    if not test:
        error = 'Please enter the right question_id'
    
    if error is None:
        readsql=('SELECT * FROM chatbot_db.assoc_dev_questions WHERE question_id=("%s")' % (question))
        cur.execute(readsql)
        result=cur.fetchone()
        result = {
          "question_id":result[0],
          "question_content":result[1],
          "answer1_content":result[2],
          "answer2_content":result[3],
          "answer3_content":result[4],
          "answer4_content":result[5],
          "true_answer":result[6],
          "true_answer_decribe_content" : result[7],
          "external_link": result[8]
        }
        
        
        return jsonify(result)
    
    
    result = {"status_describe":"{}".format(error)}
    
    return jsonify(result)

# %%
if __name__=='__main__':
    app.run(host='0.0.0.0',port=5000)
# Out:
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 192.168.122.1 - - [07/Sep/2018 12:28:17] "GET /question/sysops?question_id=1 HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:28:47] "GET /users HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:29:18] "GET /users/abcDemo HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:30:14] "POST /users HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:32:19] "GET /users HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:32:26] "POST /users HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:32:34] "GET /users/abc HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:32:53] "GET /users HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:32:58] "POST /users HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:33:00] "GET /users HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:33:09] "POST /menu HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:33:14] "POST /menu HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:33:47] "GET /question/sysops?question_id=2 HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:33:53] "GET /question/sysops?question_id=1 HTTP/1.1" 200 -
# 192.168.122.1 - - [07/Sep/2018 12:35:07] "GET /question/sysops?question_id=1 HTTP/1.1" 200 -
